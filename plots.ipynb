# %%
import re
import pathlib as pl
import tomllib
import colorsys
import matplotlib
import dataclasses
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from functools import cached_property, partial
from itertools import batched
from matplotlib.markers import MarkerStyle
from matplotlib.transforms import Affine2D
from tqdm.contrib.concurrent import process_map
from tqdm.notebook import tqdm

from common.project import UnzippedProject
from scatterplots import hr, load_tsv_file, load_txt, EpochInfo, plot_netsize_from_epochs
from swarmsim.yaml import safe_load

from seaborn.categorical import _CategoricalPlotter  # pyright: ignore[reportAttributeAccessIssue]
from seaborn.utils import _scatter_legend_artist, _default_color  # pyright: ignore[reportAttributeAccessIssue]

# %%
matplotlib.rcParams['axes.titlesize'] = 14
matplotlib.rcParams['axes.labelsize'] = 12
# matplotlib.rcParams['legend.fontsize'] = 10
# matplotlib.rcParams['figure.dpi'] = 300
# matplotlib.rcParams['savefig.dpi'] = 300

sideways_dia = MarkerStyle('d', None, Affine2D().rotate_deg(90))

# %matplotlib widget

# %%
class Run(UnzippedProject):
    @cached_property
    def fitness_df(self):
        data = load_tsv_file(self.popfit_path)
        df = pd.DataFrame(data).T
        df.index = ('time', 'epoch', 'fitnesses')
        df = df.T
        df['time'] = df['time'].astype(float)
        df['epoch'] = df['epoch'].astype(int)
        df['fitnesses'] = df['fitnesses'].apply(eval)
        return df

# %%
folder = pl.Path('~/250108').expanduser()

projects = [Run(p) for p in folder.iterdir() if p.is_dir()]

# %%
fitnesses_per_run = [max(p.fitness_df['fitnesses'], default=0) for p in projects]
fitnesses_per_epoch = list(zip(*fitnesses_per_run))
# epoch_idxs = range(len(fitnesses_per_run[0]))

# %%
fig, ax = plt.subplots(1, 1)
ax: plt.Axes

for p in projects:
    best_fitness_per_epoch = p.fitness_df['fitnesses'].apply(max)
    n_robots = p.env['spawners'][0]['n']
    color = cm.RdBu((n_robots - 3)/8) if n_robots != 7 else 'gray'
    ax.plot(p.fitness_df['epoch'], best_fitness_per_epoch, alpha=0.7, c=color, label=n_robots)

plt.xlabel("Epochs")
plt.ylabel("Fitness")
plt.title("Population Best Fitness during G.A. for N agents")
# make legend of unique labels, sorted by label
d = {int(label): handle for handle, label in zip(*ax.get_legend_handles_labels())}
labels = sorted(d.keys())[::-1]
handles = [d[label] for label in labels]
ax.legend(handles, labels, loc='lower right', framealpha=1.0)
# %matplotlib widget
# plt.savefig('popfit_n.pdf')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
folder = pl.Path('~/neuromorphic/results/sp25').expanduser()


def extract_tenn2_maxs(project):
    with Run(project) as p:
        _t, _e, fitnesses, *_ = p.read_popfit()
        arr = np.array([li for li in fitnesses if li])
        # epoch_idxs = np.indices(arr.shape)[0]
        max_fitness = np.max(arr)
        n_robots = p.env['spawners'][0]['n']
        # print(f"{p.name}\t{behavior.name}\tN: {n_robots}\tmax: {max_fitness}")
        behavior = p.env['metrics'][0]['name']
        behavior = behavior.replace('Delaunay Dispersal', 'Delaunay Diffusion')
        return {
            'behavior': behavior,
            'n_robots': n_robots,
            'max_fitness': max_fitness,
        }


files = [pzip for behavior in folder.iterdir()
         for pzip in list(behavior.iterdir()) if behavior.name != 'diffusion']

test = extract_tenn2_maxs(next(iter(files)))
test
# Out:
# {'behavior': 'InteragentDispersion',
#  'n_robots': 7,
#  'max_fitness': np.float64(7.862073704039821)}

# %%
finalfits = process_map(extract_tenn2_maxs, files)

df1 = pd.DataFrame(finalfits)
df1
# Out:
#   0%|          | 0/297 [00:00<?, ?it/s]
#                  behavior  n_robots  max_fitness
# 0    InteragentDispersion         7     7.862074
# 1    InteragentDispersion         8     8.007349
# 2    InteragentDispersion         5     8.550547
# 3    InteragentDispersion         4     8.890730
# 4    InteragentDispersion         9     7.866218
# ..                    ...       ...          ...
# 292            Circliness         8     0.788847
# 293            Circliness         8     0.391615
# 294            Circliness         4     0.940860
# 295            Circliness         7     0.837170
# 296            Circliness         6     0.808084
#
# [297 rows x 3 columns]

# %%
def plot_strips(
    self,
    jitter,
    dodge,
    color,
    plot_kws,
):

    width = .8 * self._native_width
    offsets = self._nested_offsets(width, dodge)

    if jitter is True:
        jlim = 0.1
    else:
        jlim = float(jitter)
    if "hue" in self.variables and dodge and self._hue_map.levels is not None:
        jlim /= len(self._hue_map.levels)
    jlim *= self._native_width
    jitterer = partial(np.random.uniform, low=-jlim, high=+jlim)

    iter_vars = [self.orient]
    if dodge:
        iter_vars.append("hue")

    ax = self.ax
    dodge_move = jitter_move = 0

    if "marker" in plot_kws and not MarkerStyle(plot_kws["marker"]).is_filled():
        plot_kws.pop("edgecolor", None)

    using_facets = 'row' in iter_vars or 'col' in iter_vars or self.ax is None
    # add twinx axes for each hue level
    if not using_facets:
        axs = [self.ax]
        for _ in range(1, len(self._hue_map.levels)):
            axs.append(self.ax.twinx())

    for sub_vars, sub_data in self.iter_data(iter_vars,
                                                from_comp_data=True,
                                                allow_empty=True):

        if using_facets:
            ax = self._get_axes(sub_vars)
        else:
            assert sub_data["hue"].nunique() == 1
            cat = sub_data["hue"].iloc[0]
            idx = self._hue_map.levels.index(cat)
            ax = axs[idx]
            if idx > 1:
                offset = 1 + (idx - 1) * 0.2
                ax.spines.right.set_position(('axes', offset))
        ax: plt.Axes

        if offsets is not None and (offsets != 0).any():
            dodge_move = offsets[sub_data["hue"].map(self._hue_map.levels.index)]

        jitter_move = jitterer(size=len(sub_data)) if len(sub_data) > 1 else 0

        adjusted_data = sub_data[self.orient] + dodge_move + jitter_move
        sub_data[self.orient] = adjusted_data
        self._invert_scale(ax, sub_data)

        points = ax.scatter(sub_data["x"], sub_data["y"], color=color, **plot_kws)
        if "hue" in self.variables:
            points.set_facecolors(self._hue_map(sub_data["hue"]))
        if not using_facets:
            colors = points.get_facecolors()
            avg_color = np.mean(colors, axis=0)
            if len(avg_color) > 3:
                avg_color[3] = 1.0
            ax.tick_params(axis='y', colors=avg_color)
            ax_oriented = ax.yaxis if self.orient == 'x' else ax.xaxis
            ax_oriented.label.set(text=cat, color=avg_color)

    self._configure_legend(ax, _scatter_legend_artist, common_kws=plot_kws)


_CategoricalPlotter.plot_strips = plot_strips

# %%
palette = sns.color_palette('deep', 3)
palette.reverse()
palette.extend(sns.color_palette('deep')[3:])
bpalette = {
    'dispersion': palette[0],
    'Dispersion': palette[0],
    'InteragentDispersion': palette[0],
    'aggregation': palette[1],
    'Aggregation': palette[1],
    'milling': palette[2],
    'Circliness': palette[2],
    'diffusion': palette[3],
    'Delaunay Diffusion': palette[3],
}
palette
# Out:
# [(0.3333333333333333, 0.6588235294117647, 0.40784313725490196),
#  (0.8666666666666667, 0.5176470588235295, 0.3215686274509804),
#  (0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#  (0.7686274509803922, 0.3058823529411765, 0.3215686274509804),
#  (0.5058823529411764, 0.4470588235294118, 0.7019607843137254),
#  (0.5764705882352941, 0.47058823529411764, 0.3764705882352941),
#  (0.8549019607843137, 0.5450980392156862, 0.7647058823529411),
#  (0.5490196078431373, 0.5490196078431373, 0.5490196078431373),
#  (0.8, 0.7254901960784313, 0.4549019607843137),
#  (0.39215686274509803, 0.7098039215686275, 0.803921568627451)]

# %%
fig = plt.figure()
sns.stripplot(data=df1, x='n_robots', y='max_fitness', hue='behavior',
              jitter=True, dodge=True, alpha=0.5, zorder=1, native_scale=True,
              palette=palette[:df1['behavior'].nunique()],
              )
# fig.subplots_adjust(right=0.7)  # 4 ax
fig.subplots_adjust(right=0.78)  # 3 ax
fig.set_figwidth(7)
fig.set_figheight(4)
legend = fig.axes[-1].legend(loc='lower left')
legend.set_title('Behavior')
for lbl in legend.texts:
    lbl.set_text(lbl.get_text().removeprefix('Interagent'))

assert [ax.get_ylabel().removeprefix('Interagent') for ax in fig.axes][:3] == ['Dispersion', 'Aggregation', 'Circliness']

for i, ax in enumerate(fig.axes):
    ax = fig.axes[i]
    lbl = ax.get_ylabel().removeprefix('Interagent')
    ax.set_ylabel(f"{lbl} ($y_{i + 1}$)")

# sns.pointplot(data=df, x='n_robots', y='max_fitness', hue='behavior',
#               dodge=.8 - .8 / 4, palette='dark', markers=sideways_dia, markersize=4, linestyle='none', errorbar=('pi', 100))
plt.title('Final Fitness per Behavior vs. Number of Robots')
plt.savefig('behavior_fitness.pdf')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# project = next(iter(files))
def extract_tenn2_popfits(project):
    with Run(project) as p:
        _t, _e, fitnesses, *_ = p.read_popfit()
        arr = np.array([li for li in fitnesses if li])
        # epoch_idxs = np.indices(arr.shape)[0]
        n_robots = p.env['spawners'][0]['n']
        # print(f"{p.name}\t{behavior.name}\tN: {n_robots}\tmax: {max_fitness}")
        behavior = p.env['metrics'][0]['name']
        behavior = behavior.replace('Delaunay Dispersal', 'Delaunay Diffusion')
        return [
            {
                'behavior': behavior,
                'n_robots': n_robots,
                'max_fitness': np.max(fits),
                'epoch': epoch,
            }
            for epoch, fits in enumerate(arr)
        ]


allfits = process_map(extract_tenn2_popfits, files)

df2 = pd.DataFrame(sum(allfits, []))
df2
# Out:
#   0%|          | 0/297 [00:00<?, ?it/s]
#                     behavior  n_robots  max_fitness  epoch
# 0       InteragentDispersion         7     6.973784      0
# 1       InteragentDispersion         7     7.073532      1
# 2       InteragentDispersion         7     7.074683      2
# 3       InteragentDispersion         7     7.074683      3
# 4       InteragentDispersion         7     7.074683      4
# ...                      ...       ...          ...    ...
# 148495            Circliness         6     0.808084    495
# 148496            Circliness         6     0.808084    496
# 148497            Circliness         6     0.808084    497
# 148498            Circliness         6     0.808084    498
# 148499            Circliness         6     0.808084    499
#
# [148500 rows x 4 columns]

# %%
behaviors = df2['behavior'].unique()


def plot_behavior(behavior, sort=True):
    fig = plt.figure()
    fig.set_size_inches(7, 5)
    artists = sns.lineplot(data=df2[df2['behavior'] == behavior],
                           x='epoch', y='max_fitness', hue='n_robots',
                           errorbar=('pi', 100), palette='viridis', legend='full')
    ax = plt.gca()
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Best Population Fitness')
    ax.set_title(f'{behavior}')
    return fig, ax, artists

# %%
fig, ax, artists = plot_behavior(behaviors[0])
plt.show()
plt.savefig(f'epochs_{behaviors[0]}.pdf')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_behavior(behaviors[1])
plt.show()
plt.savefig(f'epochs_{behaviors[1]}.pdf')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_behavior(behaviors[2])
plt.show()
plt.savefig(f'epochs_{behaviors[2]}.pdf')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_behavior(behaviors[3])
plt.show()
plt.savefig(f'epochs_{behaviors[3]}.pdf')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 plot_behavior(behaviors[3])
#       2 plt.show()
#       3 plt.savefig(f'epochs_{behaviors[3]}.pdf')
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %%
def ei_dict(epochinfo: EpochInfo):
    d = dataclasses.asdict(epochinfo)
    d.update({
        "t_total": epochinfo.t_total,
        "num_neurons": epochinfo.num_neurons,
        "num_synapses": epochinfo.num_synapses,
    })
    return d

# %%
def extract_tenn2_data(project):
    with Run(project) as p:
        _t, _e, fitnesses, *_ = p.read_popfit()
        arr = np.array([li for li in fitnesses if li])
        bests = arr.max(axis=1)
        # epoch_idxs = np.indices(arr.shape)[0]
        n_robots = p.env['spawners'][0]['n']
        # print(f"{p.name}\t{behavior.name}\tN: {n_robots}\tmax: {max_fitness}")
        behavior = p.env['metrics'][0]['name']
        behavior = behavior.replace('Delaunay Dispersal', 'Delaunay Diffusion')

        lines = p.logfile.read_lines()
        epochinfos = [x for line in lines for x in [EpochInfo.from_str(line, error=False)] if x]

        return {
            'n_robots': n_robots,
            'eons_seed': p.evolver['app']['eons_seed'],
            'fitnesses': pd.Series(bests),
            'netsize': pd.DataFrame([ei_dict(ei) for ei in epochinfos]),
            # 'proj': p.name
        }


behavior_dirs = {subdir.name: [pzip for pzip in subdir.iterdir()]
         for subdir in list(folder.iterdir())}

behavior_data = {behavior: process_map(extract_tenn2_data, files)
                 for behavior, files in behavior_dirs.items()}
# Out:
#   0%|          | 0/88 [00:00<?, ?it/s]
#   0%|          | 0/88 [00:00<?, ?it/s]
#   0%|          | 0/121 [00:00<?, ?it/s]
#   0%|          | 0/121 [00:00<?, ?it/s]

# %%
from seaborn.relational import _LinePlotter


def setup_lineplotter(
    data=None, *,
    x=None, y=None, hue=None, size=None, style=None, units=None, weights=None,
    palette=None, hue_order=None, hue_norm=None,
    sizes=None, size_order=None, size_norm=None,
    dashes=True, markers=None, style_order=None,
    estimator="mean", errorbar=("ci", 95), n_boot=1000, seed=None,
    orient="x", sort=True, err_style="band", err_kws=None,
    legend="auto", ax=None, **kwargs
):
    p = _LinePlotter(
        data=data,
        variables=dict(
            x=x, y=y, hue=hue, size=size, style=style, units=units, weight=weights
        ),
        estimator=estimator, n_boot=n_boot, seed=seed, errorbar=errorbar,
        sort=sort, orient=orient, err_style=err_style, err_kws=err_kws,
        legend=legend,
    )

    p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
    p.map_size(sizes=sizes, order=size_order, norm=size_norm)
    p.map_style(markers=markers, dashes=dashes, order=style_order)

    if ax is None:
        ax = plt.gca()

    if "style" not in p.variables and not {"ls", "linestyle"} & set(kwargs):  # XXX
        kwargs["dashes"] = "" if dashes is None or isinstance(dashes, bool) else dashes

    # Other functions have color as an explicit param,
    # and we should probably do that here too
    color = kwargs.pop("color", kwargs.pop("c", None))
    kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)

    p.kwargs = kwargs
    if not p.has_xy_data:
        p.ax = ax
        return p
    p._attach(ax)
    return p


def lineplot(self):
    import matplotlib as mpl
    from seaborn.utils import normalize_kwargs, _get_transform_functions, adjust_legend_subtitles
    from seaborn._compat import groupby_apply_include_groups
    from seaborn._statistics import EstimateAggregator, WeightedAggregator
    ax = self.ax
    kws = self.kwargs
    kws = normalize_kwargs(kws, mpl.lines.Line2D)
    kws.setdefault("markeredgewidth", 0.75)
    kws.setdefault("markeredgecolor", "w")

    self.fills = []
    self.lines = {}

    # Set default error kwargs
    err_kws = self.err_kws.copy()
    if self.err_style == "band":
        err_kws.setdefault("alpha", 0.2)
    elif self.err_style == "bars":
        pass
    elif self.err_style is not None:
        err = "`err_style` must be 'band' or 'bars', not {}"
        raise ValueError(err.format(self.err_style))

    est_kws = kws.copy()
    est_kws.setdefault('linewidth', 0.5)

    # Initialize the aggregation object
    weighted = "weight" in self.plot_data
    agg = (WeightedAggregator if weighted else EstimateAggregator)(
        self.estimator, self.errorbar, n_boot=self.n_boot, seed=self.seed,
    )

    # TODO abstract variable to aggregate over here-ish. Better name?
    orient = self.orient
    if orient not in {"x", "y"}:
        err = f"`orient` must be either 'x' or 'y', not {orient!r}."
        raise ValueError(err)
    other = {"x": "y", "y": "x"}[orient]

    # Loop over the semantic subsets and add to the plot
    grouping_vars = "hue", "size", "style"
    for sub_vars, sub_data in self.iter_data(grouping_vars, from_comp_data=True):

        if self.sort:
            sort_vars = ["units", orient, other]
            sort_cols = [var for var in sort_vars if var in self.variables]
            sub_data = sub_data.sort_values(sort_cols)

        if (
            self.estimator is not None
            and sub_data[orient].value_counts().max() > 1
        ):
            if "units" in self.variables:
                # TODO eventually relax this constraint
                err = "estimator must be None when specifying units"
                raise ValueError(err)
            grouped = sub_data.groupby(orient, sort=self.sort)
            # Could pass as_index=False instead of reset_index,
            # but that fails on a corner case with older pandas.
            sub_data = (
                grouped
                .apply(agg, other, **groupby_apply_include_groups(False))
                .reset_index()
            )
        else:
            sub_data[f"{other}min"] = np.nan
            sub_data[f"{other}max"] = np.nan

        # Apply inverse axis scaling
        for var in "xy":
            _, inv = _get_transform_functions(ax, var)
            for col in sub_data.filter(regex=f"^{var}"):
                sub_data[col] = inv(sub_data[col])

        # --- Draw the main line(s)

        if "units" in self.variables:   # XXX why not add to grouping variables?
            lines = []
            for _, unit_data in sub_data.groupby("units"):
                lines.extend(ax.plot(unit_data["x"], unit_data["y"], **kws))
        else:
            lines = []
            # lines = ax.plot(sub_data["x"], sub_data["y"], **kws)
            lines.extend(ax.plot(sub_data["x"], sub_data[f"{other}min"], **est_kws))
            lines.extend(ax.plot(sub_data["x"], sub_data[f"{other}max"], **est_kws))

        for line in lines:

            if "hue" in sub_vars:
                line.set_color(self._hue_map(sub_vars["hue"]))
                # pass

            if "size" in sub_vars:
                line.set_linewidth(self._size_map(sub_vars["size"]))

            if "style" in sub_vars:
                attributes = self._style_map(sub_vars["style"])
                if "dashes" in attributes:
                    line.set_dashes(attributes["dashes"])
                if "marker" in attributes:
                    line.set_marker(attributes["marker"])

        line_color = line.get_color()
        line_alpha = line.get_alpha()
        line_capstyle = line.get_solid_capstyle()

        # --- Draw the confidence intervals

        if self.estimator is not None and self.errorbar is not None:

            # TODO handling of orientation will need to happen here

            if self.err_style == "band":

                func = {"x": ax.fill_between, "y": ax.fill_betweenx}[orient]
                self.fills.append(func(
                    sub_data[orient],
                    sub_data[f"{other}min"], sub_data[f"{other}max"],
                    color=line_color,
                    # facecolor='#1234560f',
                    **err_kws
                ))

            elif self.err_style == "bars":
                raise NotImplementedError

    # Finalize the axes details
    self._add_axis_labels(ax)
    if self.legend:
        legend_artist = partial(mpl.lines.Line2D, xdata=[], ydata=[])
        attrs = {"hue": "color", "size": "linewidth", "style": None}
        self.add_legend_data(ax, legend_artist, kws, attrs)
        handles, _ = ax.get_legend_handles_labels()
        if handles:
            legend = ax.legend(title=self.legend_title)
            adjust_legend_subtitles(legend)

# %%
def find_best(df):
    temp_df = df.reset_index()
    return (temp_df.iloc[temp_df.idxmax()['max_fitness']]
            [['eons_seed', 'n_robots']].to_dict())


def find_df_by(behavior_data, n_robots, eons_seed):
    for d in behavior_data:
        if d['n_robots'] == n_robots and d['eons_seed'] == eons_seed:
            return d


# build df of fitnesses per eons_seed
lfdfs = {}
for behavior, data in behavior_data.items():
    lfdf = pd.DataFrame()
    for d in data:
        if any(lfdf) and (any((lfdf['eons_seed'] == d['eons_seed']) & (lfdf['n_robots'] == d['n_robots']))):
            continue  # skip duplicate
        df = pd.DataFrame(d['fitnesses'], columns=['max_fitness'])
        df.index.name = 'epoch'
        df['eons_seed'] = d['eons_seed']
        df['n_robots'] = d['n_robots']
        lfdf = pd.concat([lfdf, df], axis=0)
    lfdfs[behavior] = lfdf

# %%
def plot_best_shadow(df, fig=None, ax=None):
    if fig is None and ax is None:
        fig, ax = plt.subplots()
    elif not ax:
        ax = fig.subplots()
    p = setup_lineplotter(data=df,
                        x='epoch', y='max_fitness', hue='n_robots', style='n_robots',
                        errorbar=('pi', 100), legend='full', palette='viridis',
                        ax=ax
                        )
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Best Population Fitness')
    # ax.fill_between(df.index, df['max_fitness'], df['max_fitness'])
    # ax.set_title(f'{behavior}')
    lineplot(p)
    for n_robots in sorted(df['n_robots'].unique()):
        sub_data = df[df['n_robots'] == n_robots]
        best_seed = sub_data.groupby('eons_seed').max().idxmax()['max_fitness']
        best_data = sub_data[sub_data['eons_seed'] == best_seed]
        lines = ax.plot(best_data.index, best_data['max_fitness'])
        for line in lines:
            if "hue" in p.variables:
                line.set_color(p._hue_map(n_robots))
            if "size" in p.variables:
                line.set_linewidth(p._size_map(n_robots))
            if "style" in p.variables:
                attributes = p._style_map(n_robots)
                if "dashes" in attributes:
                    line.set_dashes(attributes["dashes"])
                if "marker" in attributes:
                    line.set_marker(attributes["marker"])
    return fig, ax, p

# %%
def plot_shadow_netsize(behavior, title=None):
    fig = plt.figure(layout="constrained")
    fig.set_size_inches(7, 6)
    figs = fig.subfigures(2, 1, height_ratios=[1, 0.5], hspace=0.02)
    _fig, ax, p = plot_best_shadow(lfdfs[behavior], fig=figs[0])
    plt.gca().set_title(behavior if title is None else title)
    plot_netsize_from_epochs(figs[1], figs[1].subplots(),
                            find_df_by(behavior_data[behavior], **find_best(lfdfs[behavior]))['netsize'])
    plt.savefig(f'epochs_combi_{behavior}.pdf')
    return fig, p

# %%
def plot_epochs_netsize(behavior, title=None):
    fig = plt.figure(layout="constrained")
    axs = fig.subplots(2, 1, sharex=True, gridspec_kw={'height_ratios': [1, 0.5]})
    data = find_df_by(behavior_data[behavior], **find_best(lfdfs[behavior]))
    axs[0].plot(data['fitnesses'].index, data['fitnesses'], color=bpalette[behavior])
    # plt.gca().set_title(behavior if title is None else title)
    plot_netsize_from_epochs(fig, axs[1], data['netsize'])
    fig.set_size_inches(7, 3)
    legend = axs[1].get_legend()
    plt.savefig(f'epochs_netsize_{behavior}.pdf')
    return fig, p


plot_epochs_netsize('milling')
# Out:
# /mnt/c/Users/kenbl/OneDrive/Documents/.projects/blimplab/neuromorphic/turtwig/scatterplots.py:209: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#
# /mnt/c/Users/kenbl/OneDrive/Documents/.projects/blimplab/neuromorphic/turtwig/scatterplots.py:211: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
# (<Figure size 700x300 with 2 Axes>, <__main__.Run at 0x7a3254886ba0>)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
behaviorset = ['dispersion', 'aggregation', 'milling']
fig = plt.figure(layout="constrained")
axs = fig.subplots(len(behaviorset) * 2, 1, sharex=True, gridspec_kw={'height_ratios': [1, 1] * len(behaviorset)})
for behavior, (ax0, ax1) in zip(behaviorset, batched(axs, 2)):
    best = find_best(lfdfs[behavior])
    data = find_df_by(behavior_data[behavior], **best)
    lbl = f'{behavior}'.title() if behavior != 'milling' else 'Circliness'
    ax0.plot(data['fitnesses'].index, data['fitnesses'], color=bpalette[behavior],
             label=lbl + f" trained w/ {int(best['n_robots'])} agents")
    ax0.legend(loc='lower right')
    # plt.gca().set_title(behavior if title is None else title)
    plot_netsize_from_epochs(fig, ax1, data['netsize'])
    ax1.set_xlabel('')
    ax1.set_title('')
    ax1.get_legend().set_title(lbl)
    ax1.get_legend().set_loc('upper center')
ax1.set_xlabel('Epochs')
fig.set_size_inches(7, 2.5 * len(behaviorset))
fig.savefig('epochs_fitness_netsize_3behaviors.pdf')
# Out:
# /mnt/c/Users/kenbl/OneDrive/Documents/.projects/blimplab/neuromorphic/turtwig/scatterplots.py:209: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#
# /mnt/c/Users/kenbl/OneDrive/Documents/.projects/blimplab/neuromorphic/turtwig/scatterplots.py:211: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#
# /mnt/c/Users/kenbl/OneDrive/Documents/.projects/blimplab/neuromorphic/turtwig/scatterplots.py:209: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#
# /mnt/c/Users/kenbl/OneDrive/Documents/.projects/blimplab/neuromorphic/turtwig/scatterplots.py:211: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#
# /mnt/c/Users/kenbl/OneDrive/Documents/.projects/blimplab/neuromorphic/turtwig/scatterplots.py:209: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#
# /mnt/c/Users/kenbl/OneDrive/Documents/.projects/blimplab/neuromorphic/turtwig/scatterplots.py:211: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# plot three behaviors over epochs
fig = plt.figure(layout="constrained")
fig.set_size_inches(7, 11)
# figs = fig.subfigures(3, 1, height_ratios=None, wspace=0.1)
axs = fig.subplots(3, 1, sharex=True)
for i, (behavior, newname) in enumerate(zip(
    ['dispersion', 'aggregation', 'milling'],
    ['Dispersion', 'Aggregation', 'Circliness']
)):
    _fig, ax, p = plot_best_shadow(lfdfs[behavior], fig=fig, ax=axs[i])
    ax.set_xlabel('')
    ax.set_ylabel(f'Best Population {newname} ($y_{i + 1}$)')
# hide legend
ax.get_legend().remove()
ax.set_xlabel('Epoch')
fig.suptitle('Fitness Evolution', fontsize=16)
plt.savefig(f'epochs_3behaviors.pdf')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
find_df_by(behavior_data['aggregation'], **find_best(lfdfs['aggregation']))['netsize']
# Out:
#        i       t_start  t_fitness  t_eons         t_end  t_elapsed  \
# 0      1  1.753814e+09     3.2744  0.0019  1.753814e+09     3.2766
# 1      2  1.753814e+09     3.1566  0.0015  1.753814e+09     3.1583
# 2      3  1.753814e+09     3.1992  0.0016  1.753814e+09     3.2010
# 3      4  1.753814e+09     3.2098  0.0012  1.753814e+09     3.2112
# 4      5  1.753814e+09     3.2845  0.0024  1.753814e+09     3.2870
# ..   ...           ...        ...     ...           ...        ...
# 495  496  1.753816e+09     3.0030  0.0022  1.753816e+09     3.0053
# 496  497  1.753816e+09     3.1951  0.0019  1.753816e+09     3.1972
# 497  498  1.753816e+09     3.0147  0.0021  1.753816e+09     3.0170
# 498  499  1.753816e+09     2.9458  0.0020  1.753816e+09     2.9480
# 499  500  1.753816e+09     3.0281  0.0021  1.753816e+09     3.0304
#
#     best_net_id best_network  best_fitness  best_score validation fitnesses  \
# 0          None         None       -0.9704     -0.9704       None        ()
# 1          None         None       -0.9704     -0.9704       None        ()
# 2          None         None       -0.8582     -0.8582       None        ()
# 3          None         None       -0.8582     -0.8582       None        ()
# 4          None         None       -0.8582     -0.8582       None        ()
# ..          ...          ...           ...         ...        ...       ...
# 495        None         None       -0.2002     -0.2002       None        ()
# 496        None         None       -0.2002     -0.2002       None        ()
# 497        None         None       -0.2002     -0.2002       None        ()
# 498        None         None       -0.2002     -0.2002       None        ()
# 499        None         None       -0.2002     -0.2002       None        ()
#
#      t_total  num_neurons  num_synapses
# 0     3.2766           16            20
# 1     3.1583           16            19
# 2     3.2010           18            14
# 3     3.2112           16            15
# 4     3.2870           16             8
# ..       ...          ...           ...
# 495   3.0053            6             8
# 496   3.1972            6             8
# 497   3.0170            6             8
# 498   2.9480            6             8
# 499   3.0304            6             8
#
# [500 rows x 15 columns]

# %%
find_best(lfdfs['aggregation'])
# Out:
# {'eons_seed': 25.0, 'n_robots': 3.0}

# %%
dfx = lfdfs['dispersion'].reset_index()
dfx[dfx['epoch'] == 499]
# dfx
# Out:
#        epoch  max_fitness  eons_seed  n_robots
# 499      499     7.862074         25         7
# 999      499     8.007349         28         8
# 1499     499     8.550547         27         5
# 1999     499     8.890730         31         4
# 2499     499     7.866218         25         9
# ...      ...          ...        ...       ...
# 41999    499     7.751653         30         7
# 42499    499     7.961374         33         9
# 42999    499     8.595028         28         5
# 43499    499     8.900019         35         4
# 43999    499     7.900140         27         9
#
# [88 rows x 4 columns]

# %%
p = Run(r'/home/videblu/neuromorphic/results/sp25/aggregation/250729-143414-rss_snn_eons_agg-es25_n3.zip')
p.unzip()
lines = p.logfile.read_lines()
[x for line in lines for x in [EpochInfo.from_str(line, error=False)] if x]
# Out:
# [EpochInfo(i=1, t_start=1753814054.7234, t_fitness=3.2744, t_eons=0.0019, t_end=1753814058.0, t_elapsed=3.2766, best_net_id=None, best_network=None, best_fitness=-0.9704, best_score=-0.9704, validation=None, fitnesses=()),
#  EpochInfo(i=2, t_start=1753814057.8417, t_fitness=3.1566, t_eons=0.0015, t_end=1753814061.0, t_elapsed=3.1583, best_net_id=None, best_network=None, best_fitness=-0.9704, best_score=-0.9704, validation=None, fitnesses=()),
#  EpochInfo(i=3, t_start=1753814060.799, t_fitness=3.1992, t_eons=0.0016, t_end=1753814064.0, t_elapsed=3.201, best_net_id=None, best_network=None, best_fitness=-0.8582, best_score=-0.8582, validation=None, fitnesses=()),
#  EpochInfo(i=4, t_start=1753814063.7888, t_fitness=3.2098, t_eons=0.0012, t_end=1753814067.0, t_elapsed=3.2112, best_net_id=None, best_network=None, best_fitness=-0.8582, best_score=-0.8582, validation=None, fitnesses=()),
#  EpochInfo(i=5, t_start=1753814067.713, t_fitness=3.2845, t_eons=0.0024, t_end=1753814071.0, t_elapsed=3.287, best_net_id=None, best_network=None, best_fitness=-0.8582, best_score=-0.8582, validation=None, fitnesses=()),
#  EpochInfo(i=6, t_start=1753814070.8571, t_fitness=3.1409, t_eons=0.0019, t_end=1753814074.0, t_elapsed=3.1429, best_net_id=None, best_network=None, best_fitness=-0.7745, best_score=-0.7745, validation=None, fitnesses=()),
#  EpochInfo(i=7, t_start=1753814073.933, t_fitness=3.0646, t_eons=0.0022, t_end=1753814077.0, t_elapsed=3.067, best_net_id=None, best_network=None, best_fitness=-0.773, best_score=-0.773, validation=None, fitnesses=()),
#  EpochInfo(i=8, t_start=1753814076.8909, t_fitness=3.1068, t_eons=0.0021000000000000003, t_end=1753814080.0, t_elapsed=3.1091, best_net_id=None, best_network=None, best_fitness=-0.773, best_score=-0.773, validation=None, fitnesses=()),
#  EpochInfo(i=9, t_start=1753814079.8395, t_fitness=3.1584, t_eons=0.002, t_end=1753814083.0, t_elapsed=3.1605, best_net_id=None, best_network=None, best_fitness=-0.773, best_score=-0.773, validation=None, fitnesses=()),
#  EpochInfo(i=10, t_start=1753814082.7567, t_fitness=3.2407, t_eons=0.0021000000000000003, t_end=1753814086.0, t_elapsed=3.2433, best_net_id=None, best_network=None, best_fitness=-0.773, best_score=-0.773, validation=None, fitnesses=()),
#  EpochInfo(i=11, t_start=1753814086.9125, t_fitness=3.0855, t_eons=0.0018, t_end=1753814090.0, t_elapsed=3.0875, best_net_id=None, best_network=None, best_fitness=-0.6932, best_score=-0.6932, validation=None, fitnesses=()),
#  EpochInfo(i=12, t_start=1753814089.0355, t_fitness=2.9623, t_eons=0.002, t_end=1753814092.0, t_elapsed=2.9645, best_net_id=None, best_network=None, best_fitness=-0.6932, best_score=-0.6932, validation=None, fitnesses=()),
#  EpochInfo(i=13, t_start=1753814092.9217, t_fitness=3.0762, t_eons=0.0019, t_end=1753814096.0, t_elapsed=3.0783, best_net_id=None, best_network=None, best_fitness=-0.6932, best_score=-0.6932, validation=None, fitnesses=()),
#  EpochInfo(i=14, t_start=1753814095.9451, t_fitness=3.0529, t_eons=0.0019, t_end=1753814099.0, t_elapsed=3.0549, best_net_id=None, best_network=None, best_fitness=-0.6932, best_score=-0.6932, validation=None, fitnesses=()),
#  EpochInfo(i=15, t_start=1753814099.0124, t_fitness=2.9857, t_eons=0.0017, t_end=1753814102.0, t_elapsed=2.9876, best_net_id=None, best_network=None, best_fitness=-0.6932, best_score=-0.6932, validation=None, fitnesses=()),
#  EpochInfo(i=16, t_start=1753814102.1509, t_fitness=2.8473, t_eons=0.0015, t_end=1753814105.0, t_elapsed=2.8491, best_net_id=None, best_network=None, best_fitness=-0.6932, best_score=-0.6932, validation=None, fitnesses=()),
#  EpochInfo(i=17, t_start=1753814104.1551, t_fitness=2.8432, t_eons=0.0015, t_end=1753814107.0, t_elapsed=2.8449, best_net_id=None, best_network=None, best_fitness=-0.6932, best_score=-0.6932, validation=None, fitnesses=()),
#  EpochInfo(i=18, t_start=1753814107.2525, t_fitness=2.7459, t_eons=0.0015, t_end=1753814110.0, t_elapsed=2.7475, best_net_id=None, best_network=None, best_fitness=-0.5035, best_score=-0.5035, validation=None, fitnesses=()),
#  EpochInfo(i=19, t_start=1753814110.245, t_fitness=2.7528, t_eons=0.0021000000000000003, t_end=1753814113.0, t_elapsed=2.755, best_net_id=None, best_network=None, best_fitness=-0.5035, best_score=-0.5035, validation=None, fitnesses=()),
#  EpochInfo(i=20, t_start=1753814112.9953, t_fitness=3.0026, t_eons=0.0019, t_end=1753814116.0, t_elapsed=3.0047, best_net_id=None, best_network=None, best_fitness=-0.3997, best_score=-0.3997, validation=None, fitnesses=()),
#  EpochInfo(i=21, t_start=1753814115.8547, t_fitness=3.1435, t_eons=0.0017, t_end=1753814119.0, t_elapsed=3.1453, best_net_id=None, best_network=None, best_fitness=-0.2909, best_score=-0.2909, validation=None, fitnesses=()),
#  EpochInfo(i=22, t_start=1753814118.953, t_fitness=3.045, t_eons=0.0019, t_end=1753814122.0, t_elapsed=3.047, best_net_id=None, best_network=None, best_fitness=-0.2909, best_score=-0.2909, validation=None, fitnesses=()),
#  EpochInfo(i=23, t_start=1753814121.8825, t_fitness=3.115, t_eons=0.0023, t_end=1753814125.0, t_elapsed=3.1175, best_net_id=None, best_network=None, best_fitness=-0.2122, best_score=-0.2122, validation=None, fitnesses=()),
#  EpochInfo(i=24, t_start=1753814125.5332, t_fitness=3.4645, t_eons=0.0022, t_end=1753814129.0, t_elapsed=3.4668, best_net_id=None, best_network=None, best_fitness=-0.2112, best_score=-0.2112, validation=None, fitnesses=()),
#  EpochInfo(i=25, t_start=1753814128.5536, t_fitness=3.4438, t_eons=0.0025, t_end=1753814132.0, t_elapsed=3.4464, best_net_id=None, best_network=None, best_fitness=-0.2112, best_score=-0.2112, validation=None, fitnesses=()),
#  EpochInfo(i=26, t_start=1753814132.5393, t_fitness=3.4585, t_eons=0.0021000000000000003, t_end=1753814136.0, t_elapsed=3.4607, best_net_id=None, best_network=None, best_fitness=-0.2112, best_score=-0.2112, validation=None, fitnesses=()),
#  EpochInfo(i=27, t_start=1753814135.4363, t_fitness=3.5617, t_eons=0.0019, t_end=1753814139.0, t_elapsed=3.5637, best_net_id=None, best_network=None, best_fitness=-0.2112, best_score=-0.2112, validation=None, fitnesses=()),
#  EpochInfo(i=28, t_start=1753814139.5386, t_fitness=3.4595, t_eons=0.0017, t_end=1753814143.0, t_elapsed=3.4614, best_net_id=None, best_network=None, best_fitness=-0.2065, best_score=-0.2065, validation=None, fitnesses=()),
#  EpochInfo(i=29, t_start=1753814142.66, t_fitness=3.3377, t_eons=0.0021000000000000003, t_end=1753814146.0, t_elapsed=3.34, best_net_id=None, best_network=None, best_fitness=-0.2065, best_score=-0.2065, validation=None, fitnesses=()),
#  EpochInfo(i=30, t_start=1753814146.6647, t_fitness=3.3333, t_eons=0.0019, t_end=1753814150.0, t_elapsed=3.3353, best_net_id=None, best_network=None, best_fitness=-0.2065, best_score=-0.2065, validation=None, fitnesses=()),
#  EpochInfo(i=31, t_start=1753814149.7756, t_fitness=3.2224, t_eons=0.0018, t_end=1753814153.0, t_elapsed=3.2244, best_net_id=None, best_network=None, best_fitness=-0.2065, best_score=-0.2065, validation=None, fitnesses=()),
#  EpochInfo(i=32, t_start=1753814152.9102, t_fitness=3.088, t_eons=0.0016, t_end=1753814156.0, t_elapsed=3.0898, best_net_id=None, best_network=None, best_fitness=-0.2043, best_score=-0.2043, validation=None, fitnesses=()),
#  EpochInfo(i=33, t_start=1753814155.9681, t_fitness=3.0303, t_eons=0.0015, t_end=1753814159.0, t_elapsed=3.0319, best_net_id=None, best_network=None, best_fitness=-0.2043, best_score=-0.2043, validation=None, fitnesses=()),
#  EpochInfo(i=34, t_start=1753814159.0272, t_fitness=2.971, t_eons=0.0017, t_end=1753814162.0, t_elapsed=2.9728, best_net_id=None, best_network=None, best_fitness=-0.2043, best_score=-0.2043, validation=None, fitnesses=()),
#  EpochInfo(i=35, t_start=1753814161.9281, t_fitness=3.0702, t_eons=0.0015, t_end=1753814165.0, t_elapsed=3.0719, best_net_id=None, best_network=None, best_fitness=-0.2043, best_score=-0.2043, validation=None, fitnesses=()),
#  EpochInfo(i=36, t_start=1753814164.8351, t_fitness=3.1634, t_eons=0.0014, t_end=1753814168.0, t_elapsed=3.1649, best_net_id=None, best_network=None, best_fitness=-0.2043, best_score=-0.2043, validation=None, fitnesses=()),
#  EpochInfo(i=37, t_start=1753814167.9814, t_fitness=3.0169, t_eons=0.0016, t_end=1753814171.0, t_elapsed=3.0186, best_net_id=None, best_network=None, best_fitness=-0.2033, best_score=-0.2033, validation=None, fitnesses=()),
#  EpochInfo(i=38, t_start=1753814171.1075, t_fitness=2.8907, t_eons=0.0016, t_end=1753814174.0, t_elapsed=2.8925, best_net_id=None, best_network=None, best_fitness=-0.2032, best_score=-0.2032, validation=None, fitnesses=()),
#  EpochInfo(i=39, t_start=1753814174.1417, t_fitness=2.8568, t_eons=0.0014, t_end=1753814177.0, t_elapsed=2.8583, best_net_id=None, best_network=None, best_fitness=-0.2028, best_score=-0.2028, validation=None, fitnesses=()),
#  EpochInfo(i=40, t_start=1753814177.1011, t_fitness=2.8971, t_eons=0.0016, t_end=1753814180.0, t_elapsed=2.8989, best_net_id=None, best_network=None, best_fitness=-0.2028, best_score=-0.2028, validation=None, fitnesses=()),
#  EpochInfo(i=41, t_start=1753814180.1205, t_fitness=2.8778, t_eons=0.0015, t_end=1753814183.0, t_elapsed=2.8795, best_net_id=None, best_network=None, best_fitness=-0.2028, best_score=-0.2028, validation=None, fitnesses=()),
#  EpochInfo(i=42, t_start=1753814183.0544, t_fitness=2.9439, t_eons=0.0015, t_end=1753814186.0, t_elapsed=2.9456, best_net_id=None, best_network=None, best_fitness=-0.2028, best_score=-0.2028, validation=None, fitnesses=()),
#  EpochInfo(i=43, t_start=1753814186.0635, t_fitness=2.9346, t_eons=0.0017, t_end=1753814189.0, t_elapsed=2.9365, best_net_id=None, best_network=None, best_fitness=-0.2028, best_score=-0.2028, validation=None, fitnesses=()),
#  EpochInfo(i=44, t_start=1753814188.9786, t_fitness=3.0194, t_eons=0.0018, t_end=1753814192.0, t_elapsed=3.0214, best_net_id=None, best_network=None, best_fitness=-0.2028, best_score=-0.2028, validation=None, fitnesses=()),
#  EpochInfo(i=45, t_start=1753814192.2733, t_fitness=2.7247, t_eons=0.0018, t_end=1753814195.0, t_elapsed=2.7267, best_net_id=None, best_network=None, best_fitness=-0.2028, best_score=-0.2028, validation=None, fitnesses=()),
#  EpochInfo(i=46, t_start=1753814194.2325, t_fitness=2.7656, t_eons=0.0017, t_end=1753814197.0, t_elapsed=2.7675, best_net_id=None, best_network=None, best_fitness=-0.2028, best_score=-0.2028, validation=None, fitnesses=()),
#  EpochInfo(i=47, t_start=1753814197.1611, t_fitness=2.8371, t_eons=0.0015, t_end=1753814200.0, t_elapsed=2.8389, best_net_id=None, best_network=None, best_fitness=-0.2025, best_score=-0.2025, validation=None, fitnesses=()),
#  EpochInfo(i=48, t_start=1753814200.1852, t_fitness=2.813, t_eons=0.0016, t_end=1753814203.0, t_elapsed=2.8148, best_net_id=None, best_network=None, best_fitness=-0.2025, best_score=-0.2025, validation=None, fitnesses=()),
#  EpochInfo(i=49, t_start=1753814203.2158, t_fitness=2.7824, t_eons=0.0016, t_end=1753814206.0, t_elapsed=2.7842, best_net_id=None, best_network=None, best_fitness=-0.2025, best_score=-0.2025, validation=None, fitnesses=()),
#  EpochInfo(i=50, t_start=1753814206.0452, t_fitness=2.9531, t_eons=0.0015, t_end=1753814209.0, t_elapsed=2.9548, best_net_id=None, best_network=None, best_fitness=-0.2025, best_score=-0.2025, validation=None, fitnesses=()),
#  EpochInfo(i=51, t_start=1753814208.8513, t_fitness=3.147, t_eons=0.0015, t_end=1753814212.0, t_elapsed=3.1487, best_net_id=None, best_network=None, best_fitness=-0.2025, best_score=-0.2025, validation=None, fitnesses=()),
#  EpochInfo(i=52, t_start=1753814212.0726, t_fitness=2.9255, t_eons=0.0017, t_end=1753814215.0, t_elapsed=2.9274, best_net_id=None, best_network=None, best_fitness=-0.2025, best_score=-0.2025, validation=None, fitnesses=()),
#  EpochInfo(i=53, t_start=1753814214.8352, t_fitness=3.1629, t_eons=0.0017, t_end=1753814218.0, t_elapsed=3.1648, best_net_id=None, best_network=None, best_fitness=-0.2025, best_score=-0.2025, validation=None, fitnesses=()),
#  EpochInfo(i=54, t_start=1753814217.7574, t_fitness=3.2409, t_eons=0.0016, t_end=1753814221.0, t_elapsed=3.2426, best_net_id=None, best_network=None, best_fitness=-0.2025, best_score=-0.2025, validation=None, fitnesses=()),
#  EpochInfo(i=55, t_start=1753814221.0934, t_fitness=2.9048, t_eons=0.0017, t_end=1753814224.0, t_elapsed=2.9066, best_net_id=None, best_network=None, best_fitness=-0.2025, best_score=-0.2025, validation=None, fitnesses=()),
#  EpochInfo(i=56, t_start=1753814224.0534, t_fitness=2.9448, t_eons=0.0017, t_end=1753814227.0, t_elapsed=2.9466, best_net_id=None, best_network=None, best_fitness=-0.2025, best_score=-0.2025, validation=None, fitnesses=()),
#  EpochInfo(i=57, t_start=1753814226.8456, t_fitness=3.1527, t_eons=0.0016, t_end=1753814230.0, t_elapsed=3.1544, best_net_id=None, best_network=None, best_fitness=-0.2025, best_score=-0.2025, validation=None, fitnesses=()),
#  EpochInfo(i=58, t_start=1753814230.1047, t_fitness=2.8935, t_eons=0.0016, t_end=1753814233.0, t_elapsed=2.8953, best_net_id=None, best_network=None, best_fitness=-0.2021, best_score=-0.2021, validation=None, fitnesses=()),
#  EpochInfo(i=59, t_start=1753814233.0558, t_fitness=2.9423, t_eons=0.0015, t_end=1753814236.0, t_elapsed=2.9442, best_net_id=None, best_network=None, best_fitness=-0.2021, best_score=-0.2021, validation=None, fitnesses=()),
#  EpochInfo(i=60, t_start=1753814236.0395, t_fitness=2.9587, t_eons=0.0016, t_end=1753814239.0, t_elapsed=2.9605, best_net_id=None, best_network=None, best_fitness=-0.2021, best_score=-0.2021, validation=None, fitnesses=()),
#  EpochInfo(i=61, t_start=1753814239.0596, t_fitness=2.9387, t_eons=0.0015, t_end=1753814242.0, t_elapsed=2.9404, best_net_id=None, best_network=None, best_fitness=-0.2021, best_score=-0.2021, validation=None, fitnesses=()),
#  EpochInfo(i=62, t_start=1753814241.999, t_fitness=2.9992, t_eons=0.0016, t_end=1753814245.0, t_elapsed=3.001, best_net_id=None, best_network=None, best_fitness=-0.2021, best_score=-0.2021, validation=None, fitnesses=()),
#  EpochInfo(i=63, t_start=1753814245.143, t_fitness=2.8552, t_eons=0.0016, t_end=1753814248.0, t_elapsed=2.857, best_net_id=None, best_network=None, best_fitness=-0.2021, best_score=-0.2021, validation=None, fitnesses=()),
#  EpochInfo(i=64, t_start=1753814248.0216, t_fitness=2.9768, t_eons=0.0015, t_end=1753814251.0, t_elapsed=2.9784, best_net_id=None, best_network=None, best_fitness=-0.2017, best_score=-0.2017, validation=None, fitnesses=()),
#  EpochInfo(i=65, t_start=1753814251.1443, t_fitness=2.8541, t_eons=0.0015, t_end=1753814254.0, t_elapsed=2.8557, best_net_id=None, best_network=None, best_fitness=-0.2017, best_score=-0.2017, validation=None, fitnesses=()),
#  EpochInfo(i=66, t_start=1753814254.0201, t_fitness=2.9781, t_eons=0.0016, t_end=1753814257.0, t_elapsed=2.9799, best_net_id=None, best_network=None, best_fitness=-0.2017, best_score=-0.2017, validation=None, fitnesses=()),
#  EpochInfo(i=67, t_start=1753814257.0143, t_fitness=2.9839, t_eons=0.0016, t_end=1753814260.0, t_elapsed=2.9857, best_net_id=None, best_network=None, best_fitness=-0.2017, best_score=-0.2017, validation=None, fitnesses=()),
#  EpochInfo(i=68, t_start=1753814259.9526, t_fitness=3.0458, t_eons=0.0014, t_end=1753814263.0, t_elapsed=3.0474, best_net_id=None, best_network=None, best_fitness=-0.2016, best_score=-0.2015, validation=None, fitnesses=()),
#  EpochInfo(i=69, t_start=1753814263.0197, t_fitness=2.9786, t_eons=0.0015, t_end=1753814266.0, t_elapsed=2.9803, best_net_id=None, best_network=None, best_fitness=-0.2014, best_score=-0.2014, validation=None, fitnesses=()),
#  EpochInfo(i=70, t_start=1753814266.0205, t_fitness=2.9776, t_eons=0.0017, t_end=1753814269.0, t_elapsed=2.9795, best_net_id=None, best_network=None, best_fitness=-0.2014, best_score=-0.2014, validation=None, fitnesses=()),
#  EpochInfo(i=71, t_start=1753814268.976, t_fitness=3.0222, t_eons=0.0016, t_end=1753814272.0, t_elapsed=3.024, best_net_id=None, best_network=None, best_fitness=-0.2014, best_score=-0.2014, validation=None, fitnesses=()),
#  EpochInfo(i=72, t_start=1753814271.841, t_fitness=3.157, t_eons=0.0018, t_end=1753814275.0, t_elapsed=3.159, best_net_id=None, best_network=None, best_fitness=-0.2014, best_score=-0.2014, validation=None, fitnesses=()),
#  EpochInfo(i=73, t_start=1753814274.911, t_fitness=3.0873, t_eons=0.0016, t_end=1753814278.0, t_elapsed=3.089, best_net_id=None, best_network=None, best_fitness=-0.2014, best_score=-0.2014, validation=None, fitnesses=()),
#  EpochInfo(i=74, t_start=1753814278.9333, t_fitness=3.065, t_eons=0.0015, t_end=1753814282.0, t_elapsed=3.0667, best_net_id=None, best_network=None, best_fitness=-0.2014, best_score=-0.2014, validation=None, fitnesses=()),
#  EpochInfo(i=75, t_start=1753814282.0527, t_fitness=2.9453, t_eons=0.0018, t_end=1753814285.0, t_elapsed=2.9473, best_net_id=None, best_network=None, best_fitness=-0.2014, best_score=-0.2014, validation=None, fitnesses=()),
#  EpochInfo(i=76, t_start=1753814284.9986, t_fitness=2.9998, t_eons=0.0015, t_end=1753814288.0, t_elapsed=3.0014, best_net_id=None, best_network=None, best_fitness=-0.2014, best_score=-0.2014, validation=None, fitnesses=()),
#  EpochInfo(i=77, t_start=1753814287.0711, t_fitness=2.9272, t_eons=0.0015, t_end=1753814290.0, t_elapsed=2.9289, best_net_id=None, best_network=None, best_fitness=-0.2014, best_score=-0.2014, validation=None, fitnesses=()),
#  EpochInfo(i=78, t_start=1753814290.0711, t_fitness=2.9272, t_eons=0.0015, t_end=1753814293.0, t_elapsed=2.9289, best_net_id=None, best_network=None, best_fitness=-0.2014, best_score=-0.2014, validation=None, fitnesses=()),
#  EpochInfo(i=79, t_start=1753814293.0773, t_fitness=2.9211, t_eons=0.0015, t_end=1753814296.0, t_elapsed=2.9227, best_net_id=None, best_network=None, best_fitness=-0.2014, best_score=-0.2014, validation=None, fitnesses=()),
#  EpochInfo(i=80, t_start=1753814296.1104, t_fitness=2.8876, t_eons=0.0017, t_end=1753814299.0, t_elapsed=2.8896, best_net_id=None, best_network=None, best_fitness=-0.2014, best_score=-0.2014, validation=None, fitnesses=()),
#  EpochInfo(i=81, t_start=1753814299.1382, t_fitness=2.8598, t_eons=0.0018, t_end=1753814302.0, t_elapsed=2.8618, best_net_id=None, best_network=None, best_fitness=-0.2012, best_score=-0.2012, validation=None, fitnesses=()),
#  EpochInfo(i=82, t_start=1753814302.1157, t_fitness=2.8826, t_eons=0.0015, t_end=1753814305.0, t_elapsed=2.8843, best_net_id=None, best_network=None, best_fitness=-0.2012, best_score=-0.2012, validation=None, fitnesses=()),
#  EpochInfo(i=83, t_start=1753814305.1304, t_fitness=2.8679, t_eons=0.0015, t_end=1753814308.0, t_elapsed=2.8696, best_net_id=None, best_network=None, best_fitness=-0.2011, best_score=-0.2011, validation=None, fitnesses=()),
#  EpochInfo(i=84, t_start=1753814308.2365, t_fitness=2.7619, t_eons=0.0014, t_end=1753814311.0, t_elapsed=2.7635, best_net_id=None, best_network=None, best_fitness=-0.2011, best_score=-0.2011, validation=None, fitnesses=()),
#  EpochInfo(i=85, t_start=1753814311.0423, t_fitness=2.9559, t_eons=0.0016, t_end=1753814314.0, t_elapsed=2.9577, best_net_id=None, best_network=None, best_fitness=-0.2011, best_score=-0.2011, validation=None, fitnesses=()),
#  EpochInfo(i=86, t_start=1753814314.1114, t_fitness=2.887, t_eons=0.0014, t_end=1753814317.0, t_elapsed=2.8886, best_net_id=None, best_network=None, best_fitness=-0.2004, best_score=-0.2004, validation=None, fitnesses=()),
#  EpochInfo(i=87, t_start=1753814317.0828, t_fitness=2.9155, t_eons=0.0015, t_end=1753814320.0, t_elapsed=2.9172, best_net_id=None, best_network=None, best_fitness=-0.2004, best_score=-0.2004, validation=None, fitnesses=()),
#  EpochInfo(i=88, t_start=1753814320.0453, t_fitness=2.9529, t_eons=0.0016, t_end=1753814323.0, t_elapsed=2.9547, best_net_id=None, best_network=None, best_fitness=-0.2004, best_score=-0.2004, validation=None, fitnesses=()),
#  EpochInfo(i=89, t_start=1753814322.088, t_fitness=2.9102, t_eons=0.0016, t_end=1753814325.0, t_elapsed=2.912, best_net_id=None, best_network=None, best_fitness=-0.2004, best_score=-0.2004, validation=None, fitnesses=()),
#  EpochInfo(i=90, t_start=1753814325.0827, t_fitness=2.9153, t_eons=0.0018, t_end=1753814328.0, t_elapsed=2.9173, best_net_id=None, best_network=None, best_fitness=-0.2004, best_score=-0.2004, validation=None, fitnesses=()),
#  EpochInfo(i=91, t_start=1753814328.0947, t_fitness=2.9035, t_eons=0.0016, t_end=1753814331.0, t_elapsed=2.9053, best_net_id=None, best_network=None, best_fitness=-0.2004, best_score=-0.2004, validation=None, fitnesses=()),
#  EpochInfo(i=92, t_start=1753814331.0698, t_fitness=2.9283, t_eons=0.0017, t_end=1753814334.0, t_elapsed=2.9302, best_net_id=None, best_network=None, best_fitness=-0.2004, best_score=-0.2004, validation=None, fitnesses=()),
#  EpochInfo(i=93, t_start=1753814334.0317, t_fitness=2.9662, t_eons=0.0019, t_end=1753814337.0, t_elapsed=2.9683, best_net_id=None, best_network=None, best_fitness=-0.2004, best_score=-0.2004, validation=None, fitnesses=()),
#  EpochInfo(i=94, t_start=1753814337.0567, t_fitness=2.9415, t_eons=0.0016, t_end=1753814340.0, t_elapsed=2.9433, best_net_id=None, best_network=None, best_fitness=-0.2004, best_score=-0.2004, validation=None, fitnesses=()),
#  EpochInfo(i=95, t_start=1753814340.0622, t_fitness=2.936, t_eons=0.0016, t_end=1753814343.0, t_elapsed=2.9378, best_net_id=None, best_network=None, best_fitness=-0.2004, best_score=-0.2004, validation=None, fitnesses=()),
#  EpochInfo(i=96, t_start=1753814343.121, t_fitness=2.8772, t_eons=0.0016, t_end=1753814346.0, t_elapsed=2.879, best_net_id=None, best_network=None, best_fitness=-0.2004, best_score=-0.2004, validation=None, fitnesses=()),
#  EpochInfo(i=97, t_start=1753814346.0676, t_fitness=2.9304, t_eons=0.0018, t_end=1753814349.0, t_elapsed=2.9324, best_net_id=None, best_network=None, best_fitness=-0.2004, best_score=-0.2004, validation=None, fitnesses=()),
#  EpochInfo(i=98, t_start=1753814349.0338, t_fitness=2.9643, t_eons=0.0017, t_end=1753814352.0, t_elapsed=2.9662, best_net_id=None, best_network=None, best_fitness=-0.2004, best_score=-0.2004, validation=None, fitnesses=()),
#  EpochInfo(i=99, t_start=1753814352.064, t_fitness=2.9339, t_eons=0.0019, t_end=1753814355.0, t_elapsed=2.936, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=100, t_start=1753814354.9885, t_fitness=3.0098, t_eons=0.0016, t_end=1753814358.0, t_elapsed=3.0115, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=101, t_start=1753814358.034, t_fitness=2.9642, t_eons=0.0016, t_end=1753814361.0, t_elapsed=2.966, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=102, t_start=1753814361.0702, t_fitness=2.9278, t_eons=0.0018, t_end=1753814364.0, t_elapsed=2.9298, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=103, t_start=1753814364.0898, t_fitness=2.9084, t_eons=0.0016, t_end=1753814367.0, t_elapsed=2.9102, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=104, t_start=1753814366.9186, t_fitness=3.0796, t_eons=0.0017, t_end=1753814370.0, t_elapsed=3.0814, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=105, t_start=1753814369.9639, t_fitness=3.0342, t_eons=0.0017, t_end=1753814373.0, t_elapsed=3.0361, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=106, t_start=1753814372.9894, t_fitness=3.0088, t_eons=0.0016, t_end=1753814376.0, t_elapsed=3.0106, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=107, t_start=1753814376.0842, t_fitness=2.9141, t_eons=0.0016, t_end=1753814379.0, t_elapsed=2.9158, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=108, t_start=1753814378.9949, t_fitness=3.003, t_eons=0.0019, t_end=1753814382.0, t_elapsed=3.0051, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=109, t_start=1753814381.9905, t_fitness=3.0075, t_eons=0.0017, t_end=1753814385.0, t_elapsed=3.0095, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=110, t_start=1753814385.034, t_fitness=2.964, t_eons=0.0018, t_end=1753814388.0, t_elapsed=2.966, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=111, t_start=1753814387.9423, t_fitness=3.0557, t_eons=0.0018, t_end=1753814391.0, t_elapsed=3.0577, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=112, t_start=1753814391.0595, t_fitness=2.9386, t_eons=0.0017, t_end=1753814394.0, t_elapsed=2.9405, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=113, t_start=1753814393.919, t_fitness=3.0793, t_eons=0.0016, t_end=1753814397.0, t_elapsed=3.081, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=114, t_start=1753814396.9856, t_fitness=3.0124, t_eons=0.0017, t_end=1753814400.0, t_elapsed=3.0144, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=115, t_start=1753814399.8874, t_fitness=3.1108, t_eons=0.0016, t_end=1753814403.0, t_elapsed=3.1126, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=116, t_start=1753814402.9981, t_fitness=3.0002, t_eons=0.0016, t_end=1753814406.0, t_elapsed=3.0019, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=117, t_start=1753814406.0961, t_fitness=2.9021, t_eons=0.0017, t_end=1753814409.0, t_elapsed=2.9039, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=118, t_start=1753814408.9865, t_fitness=3.0117, t_eons=0.0017, t_end=1753814412.0, t_elapsed=3.0135, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=119, t_start=1753814411.9725, t_fitness=3.0256, t_eons=0.0017, t_end=1753814415.0, t_elapsed=3.0275, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=120, t_start=1753814415.0077, t_fitness=2.9904, t_eons=0.0017, t_end=1753814418.0, t_elapsed=2.9923, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=121, t_start=1753814417.9726, t_fitness=3.0256, t_eons=0.0016, t_end=1753814421.0, t_elapsed=3.0274, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=122, t_start=1753814421.0256, t_fitness=2.9724, t_eons=0.0018, t_end=1753814424.0, t_elapsed=2.9744, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=123, t_start=1753814423.9944, t_fitness=3.0036, t_eons=0.0018, t_end=1753814427.0, t_elapsed=3.0056, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=124, t_start=1753814427.0126, t_fitness=2.9856, t_eons=0.0017, t_end=1753814430.0, t_elapsed=2.9874, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=125, t_start=1753814430.1045, t_fitness=2.8937, t_eons=0.0016, t_end=1753814433.0, t_elapsed=2.8955, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=126, t_start=1753814433.0576, t_fitness=2.9406, t_eons=0.0016, t_end=1753814436.0, t_elapsed=2.9424, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=127, t_start=1753814436.0506, t_fitness=2.9476, t_eons=0.0017, t_end=1753814439.0, t_elapsed=2.9494, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=128, t_start=1753814439.0647, t_fitness=2.9335, t_eons=0.0016, t_end=1753814442.0, t_elapsed=2.9353, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=129, t_start=1753814441.9987, t_fitness=2.9992, t_eons=0.0018, t_end=1753814445.0, t_elapsed=3.0013, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=130, t_start=1753814444.9555, t_fitness=3.0427, t_eons=0.0017, t_end=1753814448.0, t_elapsed=3.0445, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=131, t_start=1753814447.9529, t_fitness=3.0455, t_eons=0.0015, t_end=1753814451.0, t_elapsed=3.0471, best_net_id=None, best_network=None, best_fitness=-0.2003, best_score=-0.2003, validation=None, fitnesses=()),
#  EpochInfo(i=132, t_start=1753814451.0225, t_fitness=2.9758, t_eons=0.0015, t_end=1753814454.0, t_elapsed=2.9775, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=133, t_start=1753814453.9459, t_fitness=3.0523, t_eons=0.0017, t_end=1753814457.0, t_elapsed=3.0541, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=134, t_start=1753814456.9944, t_fitness=3.0036, t_eons=0.0018, t_end=1753814460.0, t_elapsed=3.0056, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=135, t_start=1753814460.9201, t_fitness=3.0782, t_eons=0.0015, t_end=1753814464.0, t_elapsed=3.0799, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=136, t_start=1753814463.0712, t_fitness=2.9271, t_eons=0.0016, t_end=1753814466.0, t_elapsed=2.9288, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=137, t_start=1753814466.0419, t_fitness=2.9562, t_eons=0.0016, t_end=1753814469.0, t_elapsed=2.9581, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=138, t_start=1753814469.7417, t_fitness=3.2563, t_eons=0.0018, t_end=1753814473.0, t_elapsed=3.2583, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=139, t_start=1753814472.8861, t_fitness=3.1119, t_eons=0.0018, t_end=1753814476.0, t_elapsed=3.1139, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=140, t_start=1753814476.0831, t_fitness=2.915, t_eons=0.0017, t_end=1753814479.0, t_elapsed=2.9169, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=141, t_start=1753814479.0245, t_fitness=2.9735, t_eons=0.0018, t_end=1753814482.0, t_elapsed=2.9755, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=142, t_start=1753814482.0026, t_fitness=2.9951, t_eons=0.0021000000000000003, t_end=1753814485.0, t_elapsed=2.9974, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=143, t_start=1753814485.1235, t_fitness=2.8746, t_eons=0.0018, t_end=1753814488.0, t_elapsed=2.8765, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=144, t_start=1753814488.0257, t_fitness=2.9725, t_eons=0.0016, t_end=1753814491.0, t_elapsed=2.9743, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=145, t_start=1753814491.1254, t_fitness=2.8727, t_eons=0.0017, t_end=1753814494.0, t_elapsed=2.8746, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=146, t_start=1753814494.0128, t_fitness=2.9855, t_eons=0.0016, t_end=1753814497.0, t_elapsed=2.9872, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=147, t_start=1753814496.9235, t_fitness=3.0746, t_eons=0.0017, t_end=1753814500.0, t_elapsed=3.0765, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=148, t_start=1753814500.0072, t_fitness=2.9909, t_eons=0.0017, t_end=1753814503.0, t_elapsed=2.9928, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=149, t_start=1753814503.0836, t_fitness=2.9146, t_eons=0.0016, t_end=1753814506.0, t_elapsed=2.9164, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=150, t_start=1753814506.0105, t_fitness=2.9878, t_eons=0.0016, t_end=1753814509.0, t_elapsed=2.9895, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=151, t_start=1753814508.9456, t_fitness=3.0525, t_eons=0.0017, t_end=1753814512.0, t_elapsed=3.0544, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=152, t_start=1753814512.0231, t_fitness=2.975, t_eons=0.0016, t_end=1753814515.0, t_elapsed=2.9769, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=153, t_start=1753814514.9971, t_fitness=3.0013, t_eons=0.0015, t_end=1753814518.0, t_elapsed=3.0029, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=154, t_start=1753814518.1323, t_fitness=2.8657, t_eons=0.0017, t_end=1753814521.0, t_elapsed=2.8677, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=155, t_start=1753814521.1166, t_fitness=2.8816, t_eons=0.0016, t_end=1753814524.0, t_elapsed=2.8834, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=156, t_start=1753814523.0344, t_fitness=2.9637, t_eons=0.0017, t_end=1753814526.0, t_elapsed=2.9656, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=157, t_start=1753814526.1613, t_fitness=2.8367, t_eons=0.0018, t_end=1753814529.0, t_elapsed=2.8387, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=158, t_start=1753814529.0965, t_fitness=2.9017, t_eons=0.0016, t_end=1753814532.0, t_elapsed=2.9035, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=159, t_start=1753814531.9197, t_fitness=3.0786, t_eons=0.0015, t_end=1753814535.0, t_elapsed=3.0803, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=160, t_start=1753814534.9598, t_fitness=3.0381, t_eons=0.0019, t_end=1753814538.0, t_elapsed=3.0402, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=161, t_start=1753814538.0633, t_fitness=2.9349, t_eons=0.0016, t_end=1753814541.0, t_elapsed=2.9367, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=162, t_start=1753814540.9832, t_fitness=3.0151, t_eons=0.0016, t_end=1753814544.0, t_elapsed=3.0168, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=163, t_start=1753814544.1081, t_fitness=2.8897, t_eons=0.002, t_end=1753814547.0, t_elapsed=2.8919, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=164, t_start=1753814547.1247, t_fitness=2.8737, t_eons=0.0014, t_end=1753814550.0, t_elapsed=2.8753, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=165, t_start=1753814550.0369, t_fitness=2.9615, t_eons=0.0014, t_end=1753814553.0, t_elapsed=2.9631, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=166, t_start=1753814552.9426, t_fitness=3.0554, t_eons=0.0017, t_end=1753814556.0, t_elapsed=3.0574, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=167, t_start=1753814556.0344, t_fitness=2.9638, t_eons=0.0016, t_end=1753814559.0, t_elapsed=2.9656, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=168, t_start=1753814558.9162, t_fitness=3.082, t_eons=0.0017, t_end=1753814562.0, t_elapsed=3.0838, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=169, t_start=1753814562.061, t_fitness=2.937, t_eons=0.0018, t_end=1753814565.0, t_elapsed=2.939, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=170, t_start=1753814564.9751, t_fitness=3.0231, t_eons=0.0017, t_end=1753814568.0, t_elapsed=3.0249, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=171, t_start=1753814568.1134, t_fitness=2.8848, t_eons=0.0016, t_end=1753814571.0, t_elapsed=2.8866, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=172, t_start=1753814571.0411, t_fitness=2.957, t_eons=0.0017, t_end=1753814574.0, t_elapsed=2.9589, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=173, t_start=1753814574.0738, t_fitness=2.9245, t_eons=0.0016, t_end=1753814577.0, t_elapsed=2.9262, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=174, t_start=1753814577.0354, t_fitness=2.9627, t_eons=0.0017, t_end=1753814580.0, t_elapsed=2.9646, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=175, t_start=1753814580.0392, t_fitness=2.9587, t_eons=0.0018, t_end=1753814583.0, t_elapsed=2.9608, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=176, t_start=1753814583.0701, t_fitness=2.9281, t_eons=0.0017, t_end=1753814586.0, t_elapsed=2.9299, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=177, t_start=1753814585.9589, t_fitness=3.0392, t_eons=0.0018, t_end=1753814589.0, t_elapsed=3.0411, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=178, t_start=1753814589.1054, t_fitness=2.8926, t_eons=0.0018, t_end=1753814592.0, t_elapsed=2.8946, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=179, t_start=1753814592.047, t_fitness=2.9513, t_eons=0.0015, t_end=1753814595.0, t_elapsed=2.953, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=180, t_start=1753814595.0396, t_fitness=2.9582, t_eons=0.002, t_end=1753814598.0, t_elapsed=2.9604, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=181, t_start=1753814597.9272, t_fitness=3.0709, t_eons=0.0017, t_end=1753814601.0, t_elapsed=3.0728, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=182, t_start=1753814601.0302, t_fitness=2.968, t_eons=0.0016, t_end=1753814604.0, t_elapsed=2.9698, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=183, t_start=1753814603.9186, t_fitness=3.0796, t_eons=0.0016, t_end=1753814607.0, t_elapsed=3.0814, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=184, t_start=1753814607.0476, t_fitness=2.9505, t_eons=0.0018, t_end=1753814610.0, t_elapsed=2.9524, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=185, t_start=1753814610.0695, t_fitness=2.9287, t_eons=0.0016, t_end=1753814613.0, t_elapsed=2.9305, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=186, t_start=1753814613.1025, t_fitness=2.8958, t_eons=0.0016, t_end=1753814616.0, t_elapsed=2.8975, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=187, t_start=1753814615.8875, t_fitness=3.1104, t_eons=0.0019, t_end=1753814619.0, t_elapsed=3.1125, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=188, t_start=1753814619.0453, t_fitness=2.953, t_eons=0.0015, t_end=1753814622.0, t_elapsed=2.9547, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=189, t_start=1753814621.9669, t_fitness=3.0311, t_eons=0.0018, t_end=1753814625.0, t_elapsed=3.0331, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=190, t_start=1753814624.9739, t_fitness=3.0237, t_eons=0.0022, t_end=1753814628.0, t_elapsed=3.0261, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=191, t_start=1753814627.9888, t_fitness=3.0094, t_eons=0.0017, t_end=1753814631.0, t_elapsed=3.0112, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=192, t_start=1753814630.9601, t_fitness=3.038, t_eons=0.0017, t_end=1753814634.0, t_elapsed=3.0399, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=193, t_start=1753814633.9957, t_fitness=3.0022, t_eons=0.0018, t_end=1753814637.0, t_elapsed=3.0043, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=194, t_start=1753814637.0192, t_fitness=2.9792, t_eons=0.0015, t_end=1753814640.0, t_elapsed=2.9808, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=195, t_start=1753814639.9748, t_fitness=3.0233, t_eons=0.0017, t_end=1753814643.0, t_elapsed=3.0252, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=196, t_start=1753814643.0591, t_fitness=2.9378, t_eons=0.0025, t_end=1753814646.0, t_elapsed=2.9409, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=197, t_start=1753814645.9654, t_fitness=3.0326, t_eons=0.0018, t_end=1753814649.0, t_elapsed=3.0346, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=198, t_start=1753814648.9884, t_fitness=3.0097, t_eons=0.0018, t_end=1753814652.0, t_elapsed=3.0116, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=199, t_start=1753814652.023, t_fitness=2.9753, t_eons=0.0015, t_end=1753814655.0, t_elapsed=2.977, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=200, t_start=1753814655.0798, t_fitness=2.9182, t_eons=0.0018, t_end=1753814658.0, t_elapsed=2.9202, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=201, t_start=1753814658.0525, t_fitness=2.9454, t_eons=0.0019, t_end=1753814661.0, t_elapsed=2.9475, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=202, t_start=1753814661.0778, t_fitness=2.9203, t_eons=0.0017, t_end=1753814664.0, t_elapsed=2.9222, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=203, t_start=1753814664.0205, t_fitness=2.9777, t_eons=0.0017, t_end=1753814667.0, t_elapsed=2.9795, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=204, t_start=1753814666.9812, t_fitness=3.0167, t_eons=0.0019, t_end=1753814670.0, t_elapsed=3.0188, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=205, t_start=1753814670.027, t_fitness=2.9709, t_eons=0.0019, t_end=1753814673.0, t_elapsed=2.973, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=206, t_start=1753814672.9851, t_fitness=3.0129, t_eons=0.0017, t_end=1753814676.0, t_elapsed=3.0149, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=207, t_start=1753814675.6514, t_fitness=3.3463, t_eons=0.002, t_end=1753814679.0, t_elapsed=3.3486, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=208, t_start=1753814679.0224, t_fitness=2.9759, t_eons=0.0015, t_end=1753814682.0, t_elapsed=2.9776, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=209, t_start=1753814682.9397, t_fitness=3.0584, t_eons=0.0017, t_end=1753814686.0, t_elapsed=3.0603, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=210, t_start=1753814686.0275, t_fitness=2.9704, t_eons=0.0018, t_end=1753814689.0, t_elapsed=2.9725, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=211, t_start=1753814688.9577, t_fitness=3.04, t_eons=0.002, t_end=1753814692.0, t_elapsed=3.0423, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=212, t_start=1753814692.0317, t_fitness=2.9664, t_eons=0.0017, t_end=1753814695.0, t_elapsed=2.9683, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=213, t_start=1753814694.9411, t_fitness=3.0567, t_eons=0.002, t_end=1753814698.0, t_elapsed=3.0589, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
# ...
#  EpochInfo(i=432, t_start=1753815351.6741, t_fitness=3.3237, t_eons=0.0021000000000000003, t_end=1753815355.0, t_elapsed=3.3259, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=433, t_start=1753815355.0474, t_fitness=2.9503, t_eons=0.0021000000000000003, t_end=1753815358.0, t_elapsed=2.9526, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=434, t_start=1753815358.0925, t_fitness=2.9054, t_eons=0.0019, t_end=1753815361.0, t_elapsed=2.9075, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=435, t_start=1753815361.0277, t_fitness=2.9698, t_eons=0.0022, t_end=1753815364.0, t_elapsed=2.9723, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=436, t_start=1753815364.11, t_fitness=2.8874, t_eons=0.0024, t_end=1753815367.0, t_elapsed=2.89, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=437, t_start=1753815366.9738, t_fitness=3.0241, t_eons=0.002, t_end=1753815370.0, t_elapsed=3.0262, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=438, t_start=1753815370.0333, t_fitness=2.9642, t_eons=0.0023, t_end=1753815373.0, t_elapsed=2.9667, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=439, t_start=1753815373.074, t_fitness=2.9237, t_eons=0.0021000000000000003, t_end=1753815376.0, t_elapsed=2.926, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=440, t_start=1753815375.9027, t_fitness=3.0951, t_eons=0.002, t_end=1753815379.0, t_elapsed=3.0973, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=441, t_start=1753815378.9452, t_fitness=3.0523, t_eons=0.0023, t_end=1753815382.0, t_elapsed=3.0548, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=442, t_start=1753815382.0434, t_fitness=2.9545, t_eons=0.0019, t_end=1753815385.0, t_elapsed=2.9566, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=443, t_start=1753815385.0488, t_fitness=2.949, t_eons=0.0021000000000000003, t_end=1753815388.0, t_elapsed=2.9512, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=444, t_start=1753815388.0019, t_fitness=2.9959, t_eons=0.002, t_end=1753815391.0, t_elapsed=2.9981, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=445, t_start=1753815390.9817, t_fitness=3.0161, t_eons=0.002, t_end=1753815394.0, t_elapsed=3.0183, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=446, t_start=1753815393.9302, t_fitness=3.0676, t_eons=0.0021000000000000003, t_end=1753815397.0, t_elapsed=3.0698, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=447, t_start=1753815397.0114, t_fitness=2.986, t_eons=0.0024, t_end=1753815400.0, t_elapsed=2.9886, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=448, t_start=1753815399.9967, t_fitness=3.0012, t_eons=0.002, t_end=1753815403.0, t_elapsed=3.0033, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=449, t_start=1753815403.138, t_fitness=2.86, t_eons=0.0018, t_end=1753815406.0, t_elapsed=2.862, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=450, t_start=1753815406.0168, t_fitness=2.9809, t_eons=0.0021000000000000003, t_end=1753815409.0, t_elapsed=2.9832, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=451, t_start=1753815409.0579, t_fitness=2.94, t_eons=0.0019, t_end=1753815412.0, t_elapsed=2.9421, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=452, t_start=1753815412.0697, t_fitness=2.9281, t_eons=0.002, t_end=1753815415.0, t_elapsed=2.9303, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=453, t_start=1753815415.0719, t_fitness=2.9254, t_eons=0.0025, t_end=1753815418.0, t_elapsed=2.9281, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=454, t_start=1753815417.7891, t_fitness=3.2086, t_eons=0.0021000000000000003, t_end=1753815421.0, t_elapsed=3.2109, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=455, t_start=1753815420.7141, t_fitness=3.2835, t_eons=0.0022, t_end=1753815424.0, t_elapsed=3.2859, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=456, t_start=1753815424.0619, t_fitness=2.9358, t_eons=0.0021000000000000003, t_end=1753815427.0, t_elapsed=2.9381, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=457, t_start=1753815426.9836, t_fitness=3.0144, t_eons=0.0018, t_end=1753815430.0, t_elapsed=3.0164, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=458, t_start=1753815430.079, t_fitness=2.9189, t_eons=0.0019, t_end=1753815433.0, t_elapsed=2.921, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=459, t_start=1753815433.0183, t_fitness=2.9794, t_eons=0.0021000000000000003, t_end=1753815436.0, t_elapsed=2.9817, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=460, t_start=1753815436.0157, t_fitness=2.9821, t_eons=0.002, t_end=1753815439.0, t_elapsed=2.9843, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=461, t_start=1753815438.8235, t_fitness=3.1744, t_eons=0.0019, t_end=1753815442.0, t_elapsed=3.1765, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=462, t_start=1753815441.8906, t_fitness=3.107, t_eons=0.0022, t_end=1753815445.0, t_elapsed=3.1094, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=463, t_start=1753815445.917, t_fitness=3.0806, t_eons=0.0022, t_end=1753815449.0, t_elapsed=3.083, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=464, t_start=1753815448.0963, t_fitness=2.9015, t_eons=0.002, t_end=1753815451.0, t_elapsed=2.9037, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=465, t_start=1753815451.9682, t_fitness=3.0295, t_eons=0.002, t_end=1753815455.0, t_elapsed=3.0318, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=466, t_start=1753815455.0343, t_fitness=2.9636, t_eons=0.0019, t_end=1753815458.0, t_elapsed=2.9657, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=467, t_start=1753815457.9574, t_fitness=3.0403, t_eons=0.0021000000000000003, t_end=1753815461.0, t_elapsed=3.0426, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=468, t_start=1753815460.9978, t_fitness=2.9998, t_eons=0.0022, t_end=1753815464.0, t_elapsed=3.0022, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=469, t_start=1753815463.1039, t_fitness=2.8939, t_eons=0.002, t_end=1753815466.0, t_elapsed=2.8961, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=470, t_start=1753815466.0159, t_fitness=2.9819, t_eons=0.002, t_end=1753815469.0, t_elapsed=2.9841, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=471, t_start=1753815469.0585, t_fitness=2.9393, t_eons=0.002, t_end=1753815472.0, t_elapsed=2.9415, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=472, t_start=1753815472.9583, t_fitness=3.0395, t_eons=0.002, t_end=1753815476.0, t_elapsed=3.0417, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=473, t_start=1753815475.9882, t_fitness=3.0096, t_eons=0.002, t_end=1753815479.0, t_elapsed=3.0118, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=474, t_start=1753815479.0148, t_fitness=2.983, t_eons=0.002, t_end=1753815482.0, t_elapsed=2.9852, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=475, t_start=1753815481.9388, t_fitness=3.0589, t_eons=0.002, t_end=1753815485.0, t_elapsed=3.0612, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=476, t_start=1753815484.948, t_fitness=3.0496, t_eons=0.0021000000000000003, t_end=1753815488.0, t_elapsed=3.052, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=477, t_start=1753815488.032, t_fitness=2.9655, t_eons=0.0023, t_end=1753815491.0, t_elapsed=2.968, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=478, t_start=1753815491.1304, t_fitness=2.8674, t_eons=0.0021000000000000003, t_end=1753815494.0, t_elapsed=2.8696, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=479, t_start=1753815494.0584, t_fitness=2.9393, t_eons=0.0022, t_end=1753815497.0, t_elapsed=2.9416, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=480, t_start=1753815496.0603, t_fitness=2.9375, t_eons=0.002, t_end=1753815499.0, t_elapsed=2.9397, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=481, t_start=1753815499.0696, t_fitness=2.9282, t_eons=0.002, t_end=1753815502.0, t_elapsed=2.9304, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=482, t_start=1753815502.8511, t_fitness=3.1467, t_eons=0.002, t_end=1753815506.0, t_elapsed=3.1489, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=483, t_start=1753815505.6806, t_fitness=3.3171, t_eons=0.0021000000000000003, t_end=1753815509.0, t_elapsed=3.3194, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=484, t_start=1753815509.1245, t_fitness=2.8733, t_eons=0.0021000000000000003, t_end=1753815512.0, t_elapsed=2.8755, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=485, t_start=1753815512.0408, t_fitness=2.9569, t_eons=0.0021000000000000003, t_end=1753815515.0, t_elapsed=2.9592, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=486, t_start=1753815514.9665, t_fitness=3.0312, t_eons=0.002, t_end=1753815518.0, t_elapsed=3.0335, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=487, t_start=1753815518.0426, t_fitness=2.9552, t_eons=0.0021000000000000003, t_end=1753815521.0, t_elapsed=2.9574, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=488, t_start=1753815521.1021, t_fitness=2.8956, t_eons=0.0022, t_end=1753815524.0, t_elapsed=2.8979, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=489, t_start=1753815523.8727, t_fitness=3.125, t_eons=0.0021000000000000003, t_end=1753815527.0, t_elapsed=3.1273, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=490, t_start=1753815527.1032, t_fitness=2.8945, t_eons=0.0021000000000000003, t_end=1753815530.0, t_elapsed=2.8968, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=491, t_start=1753815530.0867, t_fitness=2.911, t_eons=0.0021000000000000003, t_end=1753815533.0, t_elapsed=2.9133, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=492, t_start=1753815533.0608, t_fitness=2.9369, t_eons=0.0021000000000000003, t_end=1753815536.0, t_elapsed=2.9392, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=493, t_start=1753815535.957, t_fitness=3.0408, t_eons=0.002, t_end=1753815539.0, t_elapsed=3.043, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=494, t_start=1753815539.0385, t_fitness=2.9592, t_eons=0.0022, t_end=1753815542.0, t_elapsed=2.9615, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=495, t_start=1753815542.0725, t_fitness=2.9253, t_eons=0.002, t_end=1753815545.0, t_elapsed=2.9275, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=496, t_start=1753815544.9947, t_fitness=3.003, t_eons=0.0022, t_end=1753815548.0, t_elapsed=3.0053, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=497, t_start=1753815547.8028, t_fitness=3.1951, t_eons=0.0019, t_end=1753815551.0, t_elapsed=3.1972, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=498, t_start=1753815550.983, t_fitness=3.0147, t_eons=0.0021000000000000003, t_end=1753815554.0, t_elapsed=3.017, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=499, t_start=1753815554.052, t_fitness=2.9458, t_eons=0.002, t_end=1753815557.0, t_elapsed=2.948, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=()),
#  EpochInfo(i=500, t_start=1753815556.9696, t_fitness=3.0281, t_eons=0.0021000000000000003, t_end=1753815560.0, t_elapsed=3.0304, best_net_id=None, best_network=None, best_fitness=-0.2002, best_score=-0.2002, validation=None, fitnesses=())]

# %%
EpochInfo.from_str(lines[3])
# Out:
# EpochInfo(i=1, t_start=1753814054.7234, t_fitness=3.2744, t_eons=0.0019, t_end=1753814058.0, t_elapsed=3.2766, best_net_id=None, best_network=None, best_fitness=-0.9704, best_score=-0.9704, validation=None, fitnesses=())

# %%
plot_shadow_netsize('aggregation')
# Out:
# /mnt/c/Users/kenbl/OneDrive/Documents/.projects/blimplab/neuromorphic/turtwig/scatterplots.py:209: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.subplots_adjust(bottom=0.24)
# /mnt/c/Users/kenbl/OneDrive/Documents/.projects/blimplab/neuromorphic/turtwig/scatterplots.py:211: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.subplots_adjust(left=0.11, right=0.95)
# (<Figure size 700x600 with 2 Axes>,
#  <seaborn.relational._LinePlotter at 0x73ac8c01c410>)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
