# %%
import os
import numpy as np
from itertools import product
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

os.environ['PYGAME_HIDE_SUPPORT_PROMPT'] = '1'

import farptest
from farptest import test_mp

# %%
farptest.config = farptest.RectangularWorldConfig.from_yaml_template(
    farptest.cwd / "world.yaml",
)

results = test_mp(100, n_range=[
    *range(1, 10),
    *range(10, 30, 2),
    *range(30, 61, 5),
])
# Out:
# 100%|██████████| 100/100 [00:07<00:00, 12.78it/s]
# n:  1 Counter({'Time to Detect sub': 4818, 'Time to Capture sub': 301, 'How many red on goal': 99})
# 100%|██████████| 100/100 [00:08<00:00, 11.61it/s]
# n:  2 Counter({'Time to Detect sub': 5442, 'Time to Capture sub': 1169, 'How many red on goal': 97})
# 100%|██████████| 100/100 [00:09<00:00, 10.70it/s]
# n:  3 Counter({'Time to Detect sub': 11038, 'Time to Capture sub': 2309, 'How many red on goal': 95})
# 100%|██████████| 100/100 [00:10<00:00,  9.81it/s]
# n:  4 Counter({'Time to Detect sub': 14470, 'Time to Capture sub': 1416, 'How many red on goal': 97})
# 100%|██████████| 100/100 [00:11<00:00,  9.08it/s]
# n:  5 Counter({'Time to Detect sub': 18484, 'Time to Capture sub': 7223, 'How many red on goal': 87})
# 100%|██████████| 100/100 [00:11<00:00,  8.39it/s]
# n:  6 Counter({'Time to Detect sub': 24055, 'Time to Capture sub': 7580, 'How many red on goal': 86})
# 100%|██████████| 100/100 [00:12<00:00,  8.21it/s]
# n:  7 Counter({'Time to Detect sub': 25834, 'Time to Capture sub': 9381, 'How many red on goal': 82})
# 100%|██████████| 100/100 [00:13<00:00,  7.60it/s]
# n:  8 Counter({'Time to Detect sub': 27826, 'Time to Capture sub': 10916, 'How many red on goal': 78})
# 100%|██████████| 100/100 [00:13<00:00,  7.35it/s]
# n:  9 Counter({'Time to Detect sub': 27569, 'Time to Capture sub': 13749, 'How many red on goal': 71})
# 100%|██████████| 100/100 [00:14<00:00,  6.75it/s]
# n:  10 Counter({'Time to Detect sub': 31379, 'Time to Capture sub': 15857, 'How many red on goal': 67})
# 100%|██████████| 100/100 [00:15<00:00,  6.27it/s]
# n:  12 Counter({'Time to Detect sub': 34162, 'Time to Capture sub': 21524, 'How many red on goal': 55})
# 100%|██████████| 100/100 [00:17<00:00,  5.67it/s]
# n:  14 Counter({'Time to Detect sub': 35642, 'Time to Capture sub': 30128, 'How many red on goal': 37})
# 100%|██████████| 100/100 [00:20<00:00,  4.85it/s]
# n:  16 Counter({'Time to Detect sub': 41892, 'Time to Capture sub': 33252, 'How many red on goal': 32})
# 100%|██████████| 100/100 [00:21<00:00,  4.68it/s]
# n:  18 Counter({'Time to Detect sub': 40780, 'Time to Capture sub': 32004, 'How many red on goal': 35})
# 100%|██████████| 100/100 [00:24<00:00,  4.16it/s]
# n:  20 Counter({'Time to Detect sub': 41339, 'Time to Capture sub': 35618, 'How many red on goal': 29})
# 100%|██████████| 100/100 [00:26<00:00,  3.83it/s]
# n:  22 Counter({'Time to Detect sub': 41324, 'Time to Capture sub': 34096, 'How many red on goal': 29})
# 100%|██████████| 100/100 [00:30<00:00,  3.33it/s]
# n:  24 Counter({'Time to Detect sub': 42304, 'Time to Capture sub': 34407, 'How many red on goal': 29})
# 100%|██████████| 100/100 [00:31<00:00,  3.21it/s]
# n:  26 Counter({'Time to Detect sub': 42538, 'Time to Capture sub': 38539, 'How many red on goal': 19})
# 100%|██████████| 100/100 [00:33<00:00,  3.01it/s]
# n:  28 Counter({'Time to Detect sub': 42470, 'Time to Capture sub': 38208, 'How many red on goal': 19})
# 100%|██████████| 100/100 [00:37<00:00,  2.69it/s]
# n:  30 Counter({'Time to Detect sub': 41733, 'Time to Capture sub': 37449, 'How many red on goal': 20})
# 100%|██████████| 100/100 [00:45<00:00,  2.22it/s]
# n:  35 Counter({'Time to Detect sub': 40241, 'Time to Capture sub': 35758, 'How many red on goal': 24})
# 100%|██████████| 100/100 [00:53<00:00,  1.86it/s]
# n:  40 Counter({'Time to Detect sub': 40645, 'Time to Capture sub': 37537, 'How many red on goal': 20})
# 100%|██████████| 100/100 [01:04<00:00,  1.55it/s]
# n:  45 Counter({'Time to Detect sub': 40928, 'Time to Capture sub': 37289, 'How many red on goal': 20})
# 100%|██████████| 100/100 [01:15<00:00,  1.32it/s]
# n:  50 Counter({'Time to Detect sub': 41064, 'Time to Capture sub': 36752, 'How many red on goal': 21})
# 100%|██████████| 100/100 [01:25<00:00,  1.17it/s]
# n:  55 Counter({'Time to Capture sub': 40456, 'Time to Detect sub': 40288, 'How many red on goal': 12})
# 100%|██████████| 100/100 [01:43<00:00,  1.04s/it]
# n:  60 Counter({'Time to Detect sub': 40441, 'Time to Capture sub': 36429, 'How many red on goal': 20})
# [{'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': 577, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -388, 'Time to Detect sub': 321, 'Time to Capture sub': 388, 'How many red on goal': 0}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': 594, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect sub': -1, 'Time to Capture sub': -1, 'How many red on goal': 1}, {'n': 1, 'Time to Capture': -1000, 'Time to Detect s ...

# %%
df = pd.DataFrame(results)

# %%
# fig, ax = plt.subplots()
# pass

# %%
levy_df = df
binc_df = df

# %%
def srate(df, name='Success'):
    x = (100 - df.groupby(['n'])['How many red on goal'].mean() * 100).round().rename(f'{name} Rate')
    return x.index, x


plt.plot(*srate(levy_df), label='Levy Controller')
plt.plot(*srate(binc_df), label='B2A Controller')
plt.legend()
plt.scatter(*srate(levy_df))
plt.scatter(*srate(binc_df))
plt.title('20260525', size='small', x=0.485)
plt.suptitle('Capture Rate')
plt.xlabel('Number of Agents')
plt.ylabel('Success Rate (%)')
# ax.plot(*srate(df))
# fig
# Out:
# Text(0, 0.5, 'Success Rate (%)')

# %%
sns.countplot(data=df[df['How many red on goal'] == 0], x='n', hue='How many red on goal', palette='tab10',)
plt.ylabel("Success Rate (%)")
plt.title("Success Rate vs. N")
plt.ylim(0, 100)
plt.gca().get_legend().remove()

# %%
# sns.swarmplot(data=df, x='n', y='Time to capture', size=4)

name = 'Time to Capture'
# name = 'Time to Detect'
col = df[f'{name}'].abs()
dfm = df[(col > 0) & (col < 1000)].abs()
sns.stripplot(data=dfm, x='n', y=name, size=4, alpha=0.3)
sns.boxplot(
    dfm, x="n", y=name,
    color="c",
    # fliersize=1, whis=(5, 95)
    # palette="vlag",
    # whis=[0, 100], width=.6, palette="vlag"
)
plt.title(f"Distribution of {name} (sim timesteps) vs. n. Lower is better.")
dfm
# Out:
#        n  Time to Capture  Time to Detect sub  Time to Capture sub  \
# 12     1              388                 321                  388
# 112    2              388                 321                  388
# 165    2              465                 461                  465
# 169    2              401                 335                  401
# 212    3              388                 321                  388
# ...   ..              ...                 ...                  ...
# 2592  60              317                 272                  317
# 2594  60              495                 457                  495
# 2595  60              407                 390                  407
# 2597  60              549                 418                  549
# 2599  60              508                 458                  508
#
#       How many red on goal
# 12                       0
# 112                      0
# 165                      0
# 169                      0
# 212                      0
# ...                    ...
# 2592                     0
# 2594                     0
# 2595                     0
# 2597                     0
# 2599                     0
#
# [1319 rows x 5 columns]

# %%
with open('../../ttc_grid.csv', 'r') as f:
    cdf = pd.read_csv(f)

with open('../../ttd_grid.csv', 'r') as f:
    ddf = pd.read_csv(f)

df1 = cdf

# %%
x, y = np.meshgrid(df1['v'].unique(), df1['w'].unique())
x.flatten(), y.flatten()

counts = pd.DataFrame(df1.groupby(['v', 'w'])['How many red on goal'].sum())
plt.subplots(1, 1, layout='compressed')
plt.imshow((100 - counts.unstack().T[::-1]) / 100)
plt.xticks(
    np.arange(df1['v'].unique().size),
    [f'{v:.3f}' for v in df1['v'].unique()],
    rotation=45,
)
plt.yticks(
    np.arange(df1['w'].unique().size)[::-1],
    [f'{w:.3f}' for w in df1['w'].unique()],
    rotation=45,
)
plt.colorbar()
plt.xlabel('v forward speed (m/s)')
plt.ylabel('w left/right turn speed (rad/s)')
success = 'Capture' if df1 is cdf else 'Detection'
plt.title(f'{success} Rate w/ Binary Controller')
# plt.tight_layout()
plt.savefig(f'{success}_rate_grid.pdf')

# %%
# df1[df1['Time to detect sub'] > 0].groupby(['v', 'w']).mean()['Time to detect sub'].unstack().T[::-1]
# Out:
# v      0.000000    0.027273    0.054545    0.081818    0.109091    0.136364  \
# w
# 0.6  163.743590  165.025641  161.759494  157.645570  158.317073  153.950617
# 0.5  163.641026  166.074074  160.545455  161.101266  162.200000  156.175676
# 0.4  162.139241  164.400000  161.103896  152.065789  147.424658  149.828947
# 0.3  160.417722  158.558442  154.233766  153.272727  146.987013  149.480000
# 0.2  161.923077  155.069444  156.310811  144.735294  132.875000  128.400000
# 0.1  165.126582  146.500000  123.265306  107.292683  100.513514   93.351351
# 0.0  146.464286  131.346939  120.553191  109.522727   98.560976   86.846154
#
# v      0.163636    0.190909    0.218182    0.245455    0.272727    0.300000
# w
# 0.6  152.631579  160.162500  156.337662  150.858974  147.434211  146.987342
# 0.5  156.932432  150.868421  147.554054  147.702703  145.866667  140.447368
# 0.4  153.280000  151.337838  145.309859  140.716216  134.184211  134.040541
# 0.3  142.891892  138.915493  131.956522  127.385714  119.835821  119.846154
# 0.2  108.056604  103.229167   98.869565   89.564103   81.162162   79.000000
# 0.1   85.171429   80.818182   72.774194   70.593750   67.343750   64.343750
# 0.0   80.631579   77.648649   73.702703   71.828571   68.342857   65.060606

# %%
action = 'capture' if df1 is cdf else 'detect'
filtered = df1[df1[f'Time to {action} sub'] > 0].groupby(['v', 'w']).mean()
times = pd.DataFrame(filtered.groupby(['v', 'w']).mean())[f'Time to {action} sub']

plt.subplots(1, 1, layout='compressed')
plt.imshow((times.unstack().T[::-1]), cmap='cividis')
plt.xticks(
    np.arange(df1['v'].unique().size),
    [f'{v:.3f}' for v in df1['v'].unique()],
    rotation=45,
)
plt.yticks(
    np.arange(df1['w'].unique().size)[::-1],
    [f'{w:.3f}' for w in df1['w'].unique()],
    rotation=45,
)
plt.colorbar()
plt.xlabel('v forward speed (m/s)')
plt.ylabel('w left/right turn speed (rad/s)')
success = 'Capture' if df1 is cdf else 'Detection'
plt.title(f'Average Timesteps to {success}')
# plt.tight_layout()
plt.savefig(f'{success}_rate_grid.pdf')

# %%
counts
# Out:
#          How many red on goal
# v   w
# 0.0 0.0                    42
#     0.1                    24
#     0.2                    23
#     0.3                    23
#     0.4                    24
# ...                       ...
# 0.3 0.2                    63
#     0.3                    36
#     0.4                    27
#     0.5                    25
#     0.6                    23
#
# [84 rows x 1 columns]
